# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sun Oct 22 13:18:43 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P0    27W /  70W |    805MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/GroundingDINO/weights

# %% [markdown]
# ## Install Grounding DINO & additional dependencies
#
# Grounding DINO is still under heavy development.
#
# In addition to Grounding DINO, we will install some additional packages:
# - `roboflow` - To download and send datasets to cloud.
# - `dataclasses-json` - To make it easier to process COCO JSON and load data from disk.
# - `onemetric` - To compare the results of manual labeling with those obtained with Grounding DINO.

# %%
# %cd {HOME}
# !git clone https://github.com/IDEA-Research/GroundingDINO.git
# %cd {HOME}/GroundingDINO

# we use latest Grounding DINO model API that is not official yet
# !git checkout feature/more_compact_inference_api

# !pip install -q -e .
# !pip install -q roboflow dataclasses-json onemetric
# Out:
# /content/GroundingDINO/weights
# Cloning into 'GroundingDINO'...
# remote: Enumerating objects: 401, done.
# remote: Counting objects: 100% (166/166), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 401 (delta 130), reused 121 (delta 121), pack-reused 235
# Receiving objects: 100% (401/401), 12.84 MiB | 39.73 MiB/s, done.
# Resolving deltas: 100% (206/206), done.
# /content/GroundingDINO/weights/GroundingDINO
# Branch 'feature/more_compact_inference_api' set up to track remote branch 'feature/more_compact_inference_api' from 'origin'.
# Switched to a new branch 'feature/more_compact_inference_api'
#   Preparing metadata (setup.py) ... done

# %% [markdown]
# **NOTE:** Before we begin, let's still log the version of all the key libraries we will use.

# %%
import torch
# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)

import roboflow
import supervision

print(
    "roboflow:", roboflow.__version__,
    "; supervision:", supervision.__version__
)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0
# torch:  2.1 ; cuda:  cu118
# roboflow: 1.1.7 ; supervision: 0.4.0

# %% [markdown]
# **NOTE:** To run the Grounding DINO model we will need two things: a configuration file and a weights file. The first one is part of the repository we just cloned. The second one we need to download.

# %%
# confirm that configuration file exist

import os

CONFIG_PATH = os.path.join(HOME, "GroundingDINO/groundingdino/config/GroundingDINO_SwinT_OGC.py")
print(CONFIG_PATH, "; exist:", os.path.isfile(CONFIG_PATH))
# Out:
# /content/GroundingDINO/weights/GroundingDINO/groundingdino/config/GroundingDINO_SwinT_OGC.py ; exist: True

# %%
# download weights file

# %cd {HOME}
# !mkdir {HOME}/weights
# %cd {HOME}/weights

# !wget -q https://github.com/IDEA-Research/GroundingDINO/releases/download/v0.1.0-alpha/groundingdino_swint_ogc.pth
# Out:
# /content/GroundingDINO/weights
# mkdir: cannot create directory ‘/content/GroundingDINO/weights/weights’: File exists
# /content/GroundingDINO/weights/weights

# %%
# confirm that weights file exist

import os

WEIGHTS_PATH = os.path.join(HOME, "weights", "groundingdino_swint_ogc.pth")
print(WEIGHTS_PATH, "; exist:", os.path.isfile(WEIGHTS_PATH))
# Out:
# /content/GroundingDINO/weights/weights/groundingdino_swint_ogc.pth ; exist: True

# %% [markdown]
# ## Load model

# %%
# %cd {HOME}/GroundingDINO

from groundingdino.util.inference import Model

model = Model(model_config_path=CONFIG_PATH, model_checkpoint_path=WEIGHTS_PATH)
# Out:
# /content/GroundingDINO/weights/GroundingDINO
# final text_encoder_type: bert-base-uncased

# %%
from typing import List

def enhance_class_name(class_names: List[str]) -> List[str]:
    return [
        f"all {class_name}s"
        for class_name
        in class_names
    ]

import cv2

import supervision as sv

# %% [markdown]
# ## Dataset auto annotation

# %%
import os

def list_image_files(directory: str) -> List[str]:
    image_extensions = [".jpeg", ".jpg", ".png", ".bmp", ".gif"]
    image_files = [f for f in os.listdir(directory) if os.path.splitext(f)[1].lower() in image_extensions]
    return image_files


def save_voc_xml(xml_string: str, file_path: str) -> None:
    with open(file_path, 'w') as f:
        f.write(xml_string)


def image_name_to_xml_name(image_name: str) -> str:
    base_name, _ = os.path.splitext(image_name)
    xml_name = f"{base_name}.xml"
    return xml_name

# %% [markdown]
# ### Uploading to an empty Roboflow project

# %%
import os

PROJECT_NAME = "Custom-Bench_1"
PROJECT_DESCRIPTION = "Custom-dataset-from-eu-videos-720p"
SOURCE_DIRECTORY_PATH = os.path.join(HOME, "/content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames") # Path to new images to be added
CLASSES = ['cars', 'bikes', 'trucks', 'busses', 'scooters', 'motorcycles']
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25

# %%
from roboflow import Roboflow

workspace = Roboflow().workspace()
project = workspace.create_project(
    project_name=PROJECT_NAME,
    project_license="MIT",
    project_type="object-detection",
    annotation=PROJECT_DESCRIPTION)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-ddf51c71203b> in <cell line: 3>()
#       1 from roboflow import Roboflow
#       2
# ----> 3 workspace = Roboflow().workspace()
#       4 project = workspace.create_project(
#       5     project_name=PROJECT_NAME,
#
# /usr/local/lib/python3.10/dist-packages/roboflow/__init__.py in __init__(self, api_key, model_format, notebook)
#     249         self.notebook = notebook
#     250         self.onboarding = False
# --> 251         self.auth()
#     252
#     253     def auth(self):
#
# /usr/local/lib/python3.10/dist-packages/roboflow/__init__.py in auth(self)
#     252
#     253     def auth(self):
# --> 254         r = check_key(self.api_key, self.model_format, self.notebook)
#     255
#     256         if r == "onboarding":
#
# /usr/local/lib/python3.10/dist-packages/roboflow/__init__.py in check_key(api_key, model, notebook, num_retries)
#      18 def check_key(api_key, model, notebook, num_retries=0):
#      19     if type(api_key) is not str:
# ---> 20         raise RuntimeError(
#      21             "API Key is of Incorrect Type \n Expected Type: "
#      22             + str(type(""))
#
# RuntimeError: API Key is of Incorrect Type
#  Expected Type: <class 'str'>
#  Input Type: <class 'NoneType'>

# %% [markdown]
# ### OR uploading to an existing project/dataset:

# %%
from roboflow import Roboflow

# Initialize the Roboflow object with your API key
rf = Roboflow(api_key="...")

# Retrieve your current workspace and project name
print(rf.workspace())

# Specify the project for upload
project = rf.workspace("trafficpulse").project("custombench1")
# Out:
# loading Roboflow workspace...
# {
#   "name": "trafficpulse",
#   "url": "trafficpulse",
#   "projects": [
#     "trafficpulse/boxbike1",
#     "trafficpulse/custombench1",
#     "trafficpulse/dino1"
#   ]
# }
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# ### Detect and Upload Annotations to New Project
#
# Finally, how about putting Grounding DINO in front of a real test and using it to automatically annotate datasets. Labels will be sent to Roboflow where you can manually review them.

# %%
from os import listdir


for image_name in list_image_files(SOURCE_DIRECTORY_PATH):
    image_path = os.path.join(SOURCE_DIRECTORY_PATH, image_name)
    image = cv2.imread(image_path)
    height, width, depth = image.shape
    xml_name = image_name_to_xml_name(image_name=image_name)
    xml_path = os.path.join(SOURCE_DIRECTORY_PATH, xml_name)

    detections = model.predict_with_classes(
        image=image,
        classes=enhance_class_name(class_names=CLASSES),
        box_threshold=BOX_TRESHOLD,
        text_threshold=TEXT_TRESHOLD
    )

    # drop potential detections with phrase that is not part of CLASSES set
    detections = detections[detections.class_id != None]
    # drop potential detections with area close to area of whole image
    detections = detections[(detections.area / (height * width)) < 0.9 ]
    # drop potential double detections
    detections = detections.with_nms()

    xml_string = sv.detections_to_voc_xml(
        detections=detections,
        classes=CLASSES,
        filename=image_name,
        width=width,
        height=height,
        depth=depth
    )

    save_voc_xml(xml_string=xml_string, file_path=xml_path)
    project.upload(image_path=image_path, annotation_path=xml_path, split="train", overwrite=True)
# Out:
# Duplicate image not uploaded: /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame1545.jpg
# image already annotated: /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame1545.xml
# Duplicate image not uploaded: /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame
bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame781.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame782.xml ERROR saving annotation: save annotation for KZYKfw8ugUIcUEVpSFdU / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame782.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame783.xml ERROR saving annotation: save annotation for OZMt2xfhTZ1W6sEd0yic / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame783.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame784.xml ERROR saving annotation: save annotation for s1c4wPyTWZXEdJCjh5qJ / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame784.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame785.xml ERROR saving annotation: save annotation for PD4jb8xkJdu7HcdmDlyV / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame785.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame786.xml ERROR saving annotation: save annotation for Fke7ranWVMR4IbmPD8bv / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame786.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame787.xml ERROR saving annotation: save annotation for vb9ZILomgmTxwsadWTy0 / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame787.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame788.xml ERROR saving annotation: save annotation for UgSrx5UsJ5rY8DY4GpoW / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame788.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame789.xml ERROR saving annotation: save annotation for zaSLOIx6z13buj6JcUBp / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame789.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame790.xml ERROR saving annotation: save annotation for QJKuFWVGDpGLJGyF81Oz / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame790.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame791.xml ERROR saving annotation: save annotation for zdMTOSFaelyC8BCewc1v / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame791.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame792.xml ERROR saving annotation: save annotation for VpEjrrqpCQZIHdO070PD / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame792.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame793.xml ERROR saving annotation: save annotation for foY8u5TF4WmWUmrGts9O / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame793.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame794.xml ERROR saving annotation: save annotation for 2xxcooOZ5WIjY2Y6FHpT / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame794.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame795.xml ERROR saving annotation: save annotation for pn43nXrHWRxiQRYclxi3 / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame795.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame796.xml ERROR saving annotation: save annotation for 5kwujx6KLmxWByFlkR8G / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame796.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame797.xml ERROR saving annotation: save annotation for LySXg7xr8H2vtEosbxBJ / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame797.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame798.xml ERROR saving annotation: save annotation for 90s7YHuebVWKHb8atJfD / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame798.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame799.xml ERROR saving annotation: save annotation for 4aFZ4ZDG3SykdxCw5oVi / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame799.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame800.xml ERROR saving annotation: save annotation for cPrxr0ekIjwJlVZ2sozM / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame800.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame801.xml ERROR saving annotation: save annotation for TFSFzWn2MaZ312CvWp7c / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame801.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame802.xml ERROR saving annotation: save annotation for Bw0ixHnl3wPqYWY7ch40 / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame802.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame803.xml ERROR saving annotation: save annotation for ifISFhbb99ZC27mJmeJ7 / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame803.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame804.xml ERROR saving annotation: save annotation for Q6DOt87sHilvinNJqAch / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame804.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame805.xml ERROR saving annotation: save annotation for BJhjqbxdSTPcNE3aLNvn / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame805.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame806.xml ERROR saving annotation: save annotation for woE9NbITXhY23TJt1SyH / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame806.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame807.xml ERROR saving annotation: save annotation for Ovj5DUr2wfupG8IqUx9d / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame807.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame808.xml ERROR saving annotation: save annotation for MCq8Tldp3RyLwOhNhhqZ / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame808.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame809.xml ERROR saving annotation: save annotation for wCLuCqtFEJSAWK4Z787Q / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame809.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame810.xml ERROR saving annotation: save annotation for EuCtXac6EYUKkbcPWHyO / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame810.jpg', 'label': 'cars'}]}
# Duplicate image not uploaded: /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame811.jpg
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame811.xml ERROR saving annotation: save annotation for EuCtXac6EYUKkbcPWHyO / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame811.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame812.xml ERROR saving annotation: save annotation for 6CL12E9c8z7vA9q0UuDb / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame812.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame813.xml ERROR saving annotation: save annotation for rV0gKnkPQHitDIibnrm1 / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame813.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame814.xml ERROR saving annotation: save annotation for WDhFpYruPY0INN8Gdn65 / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame814.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame815.xml ERROR saving annotation: save annotation for q1RbijR10Wl1R7yNEq68 / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame815.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame816.xml ERROR saving annotation: save annotation for G9Koz8jMY2DL0eO0J002 / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame816.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame817.xml ERROR saving annotation: save annotation for bUpUlPm2gkb5W5VGMPas / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame817.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame818.xml ERROR saving annotation: save annotation for ypU5js5t5NbmV9jvx4c2 / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame818.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame819.xml ERROR saving annotation: save annotation for szdyz69DadxocNbBwfYK / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame819.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame820.xml ERROR saving annotation: save annotation for BkVfzZ9ZsUvIKs7Bmawz / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame820.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame821.xml ERROR saving annotation: save annotation for 7XcISauAqFkKuIZSuYYK / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame821.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame822.xml ERROR saving annotation: save annotation for TSyl0ly36uF8NE35bReF / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame822.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame823.xml ERROR saving annotation: save annotation for u6Wm5ESl6P4gcxVq67kk / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame823.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame824.xml ERROR saving annotation: save annotation for WSrWPvCYdPSNbC99GZ9S / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame824.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame825.xml ERROR saving annotation: save annotation for wLZKUaWBsA7yZ53pIwmq / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame825.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame826.xml ERROR saving annotation: save annotation for iyTfEUrb5X3rkAxUIHuk / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame826.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame827.xml ERROR saving annotation: save annotation for UHS58vbV0HsTlprmevgB / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame827.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame828.xml ERROR saving annotation: save annotation for rTesg0GQYRunj6d02y06 / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame828.jpg', 'label': 'cars'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame906.xml ERROR saving annotation: save annotation for kt0zmw85VVH2nDZOuXzs / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame906.jpg', 'label': 'trucks'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame1066.xml ERROR saving annotation: save annotation for 2Qqm0euWU17UpOszulBR / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame1066.jpg', 'label': 'busses'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame1067.xml ERROR saving annotation: save annotation for 0hSOCw6cUdiIkaI6clpI / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame1067.jpg', 'label': 'busses'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame1068.xml ERROR saving annotation: save annotation for NMwCZlYoPoeywONEXMCx / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame1068.jpg', 'label': 'busses'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame1069.xml ERROR saving annotation: save annotation for WNbWfaiAfkPICYaE96pZ / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame1069.jpg', 'label': 'busses'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame1140.xml ERROR saving annotation: save annotation for WRlYPPeeCjv2iORHQDFy / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame1140.jpg', 'label': 'bikes'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame1184.xml ERROR saving annotation: save annotation for ZcCJQ8GNUmj8kBzU0x14 / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame1184.jpg', 'label': 'trucks'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame1188.xml ERROR saving annotation: save annotation for hXBpDjukHGLC1LTkGNrp / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame1188.jpg', 'label': 'trucks'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame1519.jpg ERROR uploading image after 0 retries: Bad response: <Response [502]>
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame349.xml ERROR saving annotation: save annotation for yqAwSlbmA24l8e5Fw46i / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame349.jpg', 'label': 'bikes'}]}
# /content/drive/MyDrive/uni_life/PIP/AoM/Data/custom_frames/frame351.xml ERROR saving annotation: save annotation for YRII3i0W7HPepDSqljYu / bad response: 400: {'message': 'Invalid annotations.', 'type': 'InvalidAnnotationException', 'hint': 'All the annotations provided are invalid', 'badAnnotations': [{'type': 'warning', 'code': 'annotation:trimmed', 'key': 'frame351.jpg', 'label': 'motorcycles'}]}
